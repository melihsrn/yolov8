# %%
# pip install ultralytics

# %%
import os
HOME = os.getcwd()
print(HOME)

from IPython.display import display, Image
# Out:
# c:\Users\User\Desktop\ML\Deep Learning

# %%
import ultralytics
from ultralytics import YOLO

# model = YOLO('yolov8n-seg.pt')  # build a new model from YAML

# results = model.train(
#         batch=8,
#         device="cpu",
#         data="C:/Users/User/Desktop/Inovako/Inovako.v2i.yolov8/data.yaml",
#         epochs=7,
#         imgsz=120,
#     )

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8n-seg.pt data='C:/Users/User/Desktop/Inovako/Inovako.v2i.yolov8/data.yaml' epochs=10 imgsz=640 batch=8
# Out:
# c:\Users\User\Desktop\ML\Deep Learning
# New https://pypi.org/project/ultralytics/8.0.55 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.54  Python-3.9.13 torch-1.13.0+cpu CPU
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
# Out:
# c:\Users\User\Desktop\ML\Deep Learning

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/results.png', width=600)
# Out:
# c:\Users\User\Desktop\ML\Deep Learning

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/val_batch0_pred.jpg', width=600)
# Out:
# c:\Users\User\Desktop\ML\Deep Learning

# %%
# %cd {HOME}

# !yolo task=segment mode=val model=runs/segment/train/weights/best.pt data='C:/Users/User/Desktop/Inovako/Inovako.v2i.yolov8/data.yaml'
# Out:
# c:\Users\User\Desktop\ML\Deep Learning
# Ultralytics YOLOv8.0.54  Python-3.9.13 torch-1.13.0+cpu CPU
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
#
# val: Scanning C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\valid\labels.cache... 18 images, 0 backgrounds, 0 corrupt: 100%|██████████| 18/18 [00:00<?, ?it/s]
# val: Scanning C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\valid\labels.cache... 18 images, 0 backgrounds, 0 corrupt: 100%|██████████| 18/18 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:06<00:06,  6.59s/it]
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt conf=0.6 source='C:/Users/User/Desktop/Inovako/Inovako.v2i.yolov8/test/images' save=true
# Out:
# c:\Users\User\Desktop\ML\Deep Learning
# Ultralytics YOLOv8.0.54  Python-3.9.13 torch-1.13.0+cpu CPU
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/15 C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\test\images\110_jpg.rf.20415f8dc9cef84c867f60480bcab63e.jpg: 640x640 2 Shipss, 274.9ms
# image 2/15 C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\test\images\115_jpg.rf.f9deec8432cde4b04cf43a7a6a2519d6.jpg: 640x640 1 Ships, 211.5ms
# image 3/15 C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\test\images\121_jpg.rf.dacc0792df671a21c897ab879535f8f6.jpg: 640x640 (no detections), 222.0ms
# image 4/15 C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\test\images\21_jpg.rf.39121101319fe47bad4aa24baa79aacd.jpg: 640x640 1 Ships, 223.4ms
# image 5/15 C:\Users\User\Desktop\Inovako\Inovako.v2i.yolov8\test\images\2_jpg.rf.4f08f3511e9aff114dcd19881db928fd.jpg: 640x640 1 Ships, 191.5ms
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt conf=0.25 source='C:/Users/User/Desktop/Inovako/Dataset/Test_2/' save=true
# Out:
# c:\Users\User\Desktop\ML\Deep Learning
# Ultralytics YOLOv8.0.54  Python-3.9.13 torch-1.13.0+cpu CPU
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\12.png: 640x640 1 Dinosaurs, 234.4ms
# image 2/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\180.jpg: 640x512 1 Ships, 203.5ms
# image 3/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\199.jpg: 448x640 1 Ships, 166.1ms
# image 4/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\230.jpg: 448x640 1 Ships, 152.1ms
# image 5/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\24.png: 416x640 1 Dinosaurs, 158.1ms
# image 6/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\281.jpg: 448x640 2 Shipss, 147.6ms
# image 7/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\36.png: 416x640 2 Dinosaurss, 138.7ms
# image 8/15 C:\Users\User\Desktop\Inovako\Dataset\Test_2\37.png: 352x640 2 Dinosaurss, 125.7ms
# ...
